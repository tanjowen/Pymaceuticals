# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


import warnings
warnings.filterwarnings('ignore')


mouse_data = pd.read_csv("data/mouse_drug_data.csv")
clinical_trial_data = pd.read_csv("data/clinicaltrial_data.csv")

# Combine the data into a single dataset
combined_data = pd.merge(mouse_data, clinical_trial_data, how='outer', on='Mouse ID')

# Display the data table for preview
combined_data.head()
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
tumor_response = combined_data.groupby(['Drug', 'Timepoint'])
# Convert to DataFrame
tumor_response_mean = pd.DataFrame(tumor_response['Tumor Volume (mm3)'].mean())
# Preview DataFrame
tumor_response_mean.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325

# %%
tumor_response_mean = tumor_response_mean.reset_index()
tumor_response_mean.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0           45.000000
# 1  Capomulin          5           44.266086
# 2  Capomulin         10           43.084291
# 3  Capomulin         15           42.064317
# 4  Capomulin         20           40.716325

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint

# Convert to DataFrame
tumor_response_standerror = pd.DataFrame(tumor_response['Tumor Volume (mm3)'].sem())
# Preview DataFrame
tumor_response_standerror.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                    0.000000
#           5                    0.448593
#           10                   0.702684
#           15                   0.838617
#           20                   0.909731

# %%
tumor_response_standerror = tumor_response_standerror.reset_index()
tumor_response_standerror.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0            0.000000
# 1  Capomulin          5            0.448593
# 2  Capomulin         10            0.702684
# 3  Capomulin         15            0.838617
# 4  Capomulin         20            0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames
tumor_response_mean = tumor_response_mean.pivot(index='Timepoint', columns='Drug', values='Tumor Volume (mm3)')
# Preview that Reformatting worked
tumor_response_mean
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
# Generate the Plot (with Error Bars)

plt.errorbar(tumor_response_mean.index, tumor_response_mean["Capomulin"], yerr=tumor_response_mean['Capomulin'].sem(), 
             marker='o', linestyle='--', label='Capomulin')
plt.errorbar(tumor_response_mean.index, tumor_response_mean["Infubinol"], yerr=tumor_response_mean['Infubinol'].sem(), 
             marker='v', linestyle='--', label='Infubinol')
plt.errorbar(tumor_response_mean.index, tumor_response_mean["Ketapril"], yerr=tumor_response_mean['Ketapril'].sem(), 
             marker='^', linestyle='--', label='Ketapril')
plt.errorbar(tumor_response_mean.index, tumor_response_mean["Placebo"], yerr=tumor_response_mean['Placebo'].sem(), 
             marker='s', linestyle='--', label='Placebo')
plt.grid()
plt.legend(loc='best', fancybox=True)
plt.title("Tumor Response to Treatment")
plt.xlabel("Time (Days)")
plt.ylabel("Tumor Volume (mm3)")

# Save the Figure
plt.savefig("Charts/tumor_response.png")

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 

# Convert to DataFrame
tumor_response_meta_mean = pd.DataFrame(tumor_response['Metastatic Sites'].mean())
# Preview DataFrame
tumor_response_meta_mean.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
tumor_response_meta_mean = tumor_response_meta_mean.reset_index()
tumor_response_meta_mean.head()
# Out:
#         Drug  Timepoint  Metastatic Sites
# 0  Capomulin          0          0.000000
# 1  Capomulin          5          0.160000
# 2  Capomulin         10          0.320000
# 3  Capomulin         15          0.375000
# 4  Capomulin         20          0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 

# Convert to DataFrame
tumor_response_meta_stderror = pd.DataFrame(tumor_response['Metastatic Sites'].sem())
# Preview DataFrame
tumor_response_meta_stderror.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
tumor_response_meta_stderror = tumor_response_meta_stderror.reset_index()
tumor_response_meta_stderror.head()
# Out:
#         Drug  Timepoint  Metastatic Sites
# 0  Capomulin          0          0.000000
# 1  Capomulin          5          0.074833
# 2  Capomulin         10          0.125433
# 3  Capomulin         15          0.132048
# 4  Capomulin         20          0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames
tumor_response_meta_mean = tumor_response_meta_mean.pivot(index='Timepoint', columns='Drug', values='Metastatic Sites')
# Preview that Reformatting worked
tumor_response_meta_mean.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.320000  0.120000  0.240000   0.166667
# 10         0.565217  0.250000  0.478261   0.500000
# 15         0.764706  0.333333  0.782609   0.809524
# 20         1.000000  0.347826  0.952381   1.294118

# %%
# Generate the Plot (with Error Bars)

plt.errorbar(tumor_response_meta_mean.index, tumor_response_meta_mean["Capomulin"], yerr=tumor_response_meta_mean['Capomulin'].sem(), 
             marker='o', linestyle='--', label='Capomulin')
plt.errorbar(tumor_response_meta_mean.index, tumor_response_meta_mean["Infubinol"], yerr=tumor_response_meta_mean['Infubinol'].sem(), 
             marker='v', linestyle='--', label='Infubinol')
plt.errorbar(tumor_response_meta_mean.index, tumor_response_meta_mean["Ketapril"], yerr=tumor_response_meta_mean['Ketapril'].sem(), 
             marker='^', linestyle='--', label='Ketapril')
plt.errorbar(tumor_response_meta_mean.index, tumor_response_meta_mean["Placebo"], yerr=tumor_response_meta_mean['Placebo'].sem(), 
             marker='s', linestyle='--', label='Placebo')
plt.grid()
plt.legend(loc='best', fancybox=True)
plt.title("Metastatic Spread During Treatment")
plt.xlabel("Treatment Duration (Days)")
plt.ylabel("Met. Sites")

# Save the Figure
plt.savefig("Charts/metastatic_spread_during_treatment.png")
#Show the Figure
plt.show()

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)

# Convert to DataFrame
tumor_response_survival = pd.DataFrame(tumor_response['Mouse ID'].count())
# Preview DataFrame
tumor_response_survival.head()
# Out:
#                      Mouse ID
# Drug      Timepoint
# Capomulin 0                25
#           5                25
#           10               25
#           15               24
#           20               23

# %%
tumor_response_survival = tumor_response_survival.reset_index()
tumor_response_survival.head()
# Out:
#         Drug  Timepoint  Mouse ID
# 0  Capomulin          0        25
# 1  Capomulin          5        25
# 2  Capomulin         10        25
# 3  Capomulin         15        24
# 4  Capomulin         20        23

# %%
# Minor Data Munging to Re-Format the Data Frames
tumor_response_survival_rate = tumor_response_survival.pivot(index='Timepoint', columns='Drug', values='Mouse ID')
# Preview the Data Frame
tumor_response_survival_rate.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17

# %%
# Generate the Plot (with Error Bars)

plt.errorbar(tumor_response_survival_rate.index, (tumor_response_survival_rate["Capomulin"]/25)*100,
             marker='o', linestyle='--', label='Capomulin')
plt.errorbar(tumor_response_survival_rate.index, (tumor_response_survival_rate["Infubinol"]/25)*100,  
             marker='v', linestyle='--', label='Infubinol')
plt.errorbar(tumor_response_survival_rate.index, (tumor_response_survival_rate["Ketapril"]/25)*100, 
             marker='^', linestyle='--', label='Ketapril')
plt.errorbar(tumor_response_survival_rate.index, (tumor_response_survival_rate["Placebo"]/25)*100, 
             marker='s', linestyle='--', label='Placebo')
plt.grid()
plt.legend(loc='best', fancybox=True)
plt.title("Survival During Treatment")
plt.xlabel("Time (Days)")
plt.ylabel("Survival Rate (%)")

# Save the Figure
plt.savefig("Charts/survival_during_treatment.png")
#Show the Figure
plt.show()

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
percent_change = (((tumor_response_mean.iloc[-1]-tumor_response_mean.iloc[0])/tumor_response_mean.iloc[0])*100)
# Display the data to confirm
percent_change
# Out:
# Drug
# Capomulin   -19.475303
# Ceftamin     42.516492
# Infubinol    46.123472
# Ketapril     57.028795
# Naftisol     53.923347
# Placebo      51.297960
# Propriva     47.241175
# Ramicane    -22.320900
# Stelasyn     52.085134
# Zoniferol    46.579751
# dtype: float64

# %%
# Store all Relevant Percent Changes into a Tuple
relevant_change = (percent_change['Capomulin'], percent_change['Infubinol'],
                   percent_change['Ketapril'], percent_change['Placebo'])

# Splice the data between passing and failing drugs
fig, ax = plt.subplots()
identity = np.arange(len(relevant_change))

passing = ax.bar(identity[0], relevant_change[0], width=1, color='green')
fail = ax.bar(identity[1:], relevant_change[1:], width=1, color='red')

# Orient widths. Add labels, tick marks, etc. 
ax.set_title('Tumor Change Over 45 Day Treatment')
ax.set_ylabel('% Tumor Volume Change')
ax.set_xticks(identity+.5)
ax.set_xticklabels(('Capomulin', 'Infubinol', 'Ketapril', 'Placebo'))
ax.set_yticks([-20, 0, 20, 40, 60])
ax.grid()

# Use functions to label the percentages of changes
def autolabel(rects):
    for i in rects:
        height = i.get_height()
        ax.text(i.get_x() + i.get_width()/2., -10, '-%d' %int(height) + "%", ha='center', va='bottom', color='white')
def autolabelother(rects):
    for i in rects:
        height = i.get_height()
        ax.text(i.get_x() + i.get_width()/2., 5, '%d' %int(height) + "%", ha='center', va='bottom', color='white')

# Call functions to implement the function calls
autolabel(passing)
autolabelother(fail)

# Save the Figure
fig.savefig('Charts/change_over_45days.png')

# Show the Figure
fig.show()
